# %% [markdown]
# # Build A Python App That Tracks Amazon Prices!

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.amazon.in/Sony-ILCE-7RM3-Full-Frame-Mirrorless-Interchangeable/dp/B07DPS7ZGG/ref=sxin_7?ascsubtag=amzn1.osa.a50e260d-f0cf-4b08-8d3f-8cd25741916a.A21TJRUUN4KGV.en_IN&creativeASIN=B07DPS7ZGG&cv_ct_cx=sony+camera&cv_ct_id=amzn1.osa.a50e260d-f0cf-4b08-8d3f-8cd25741916a.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_wn=osp-single-source&dchild=1&keywords=sony+camera&linkCode=oas&pd_rd_i=B07DPS7ZGG&pd_rd_r=281083cb-dcdb-4225-a4e9-5cb59afbd028&pd_rd_w=6vhDw&pd_rd_wg=35DtI&pf_rd_p=6e76604f-4d20-4bf3-bcab-75ada7993e2a&pf_rd_r=H0FE7FR8RH6VYGSPT8MJ&qid=1595517374&sr=1-1-32235bf8-c8dc-423d-b49a-58af94d8b862&tag=technologytoday-21"

headers = {"User-Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

# %%
page = requests.get(URL, headers = headers)
soup = BeautifulSoup(page.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script>
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <script>
#    (function(a){var b=a.performance;a.ue_mark=b&&"function"===typeof b.mark?function(a){b.mark(a)}:function(){}})(window);
#
#     ue_mark('csm:ho:ob');
#   </script>
#   <script>
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
#
# if (window.ue_ihb === 1) {
#
#     var ue_csm = window,
#         ue_hob = +new Date();
# ...

# %%
title = soup.find(id ="productTitle")
print(soup.title.string)
# Out:
# Sony Alpha ILCE-7RM3 Full-Frame 42.4MP Mirrorless: Amazon.in: Electronics

# %%
price = soup.find(id ="priceblock_ourprice")
print(soup.price)
# Out:
# None

# %%
soup.find_all('tr')
# Out:
# []

# %%
p = soup.find(class = "a-size-medium a-color-price priceBlockBuyingPriceString")
print(soup.p)
# Out:
#   File "<ipython-input-62-7735a8b1282a>", line 1
#     p = soup.find(class = "a-size-medium a-color-price priceBlockBuyingPriceString")
#                       ^
# SyntaxError: invalid syntax

# %%
p1 = soup.findAll("div", {"class": "a-size-medium a-color-price priceBlockBuyingPriceString"})

print(soup.p1)
# Out:
# None
